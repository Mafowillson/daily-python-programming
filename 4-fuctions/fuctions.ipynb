# %% [markdown]
# Definition:
#
# A fuction is a block of code that performs a specific task. Functions helps in organizing code, reusing code, and improving
# readability

# %%
## Syntax

def function_name(parameters):
    """Docstring"""
    # function body
    return expression

# %%
# Why functions?

num = 24

if num % 2 == 0:
    print ("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
def even_or_odd(num):
    """This functions finds even or odd"""
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")

# %%
even_or_odd(5)
# Out:
# The number is odd

# %%
## function with multiple parameters

def add(a, b):
    """function to add two variables"""
    return a + b

result = add(2, 4)
print(result)
# Out:
# 6

# %%
## Default Parameters

def greet(name):
    print(f"Hello {name} welcome to the paradise")

greet("Willson")
# Out:
# Hello Willson welcome to the paradise

# %%
def greet(name="Guest"):
    print(f"Hello {name} welcome to the paradise")

greet()
greet("Willson")
# Out:
# Hello Guest welcome to the paradise
# Hello Willson welcome to the paradise

# %%
## Variable length arguements
## Positional and keywords arguements

# Positional arguements
def print_numbers(*args):
    for number in  args:
        print(number)

# %%
print_numbers(1, 2, 3, 4, 5, 6, 7, 8, "Krish")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Krish

# %%
# keyword arguements

# In kwargs all the parameter are in the form of key value pairs

def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_details(name = "Willson", age = 32, country = "Cameroon")
# Out:
# name: Willson
# age: 32
# country: Cameroon

# %%
# Combination

def print_details(*args, **kwargs):
    for val in args:
        print(f"Positional arguement {val}")
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_details(1, 2, 3, 4, "Willson", name = "Willson", age = 32, country = "Cameroon")
# Out:
# Positional arguement 1
# Positional arguement 2
# Positional arguement 3
# Positional arguement 4
# Positional arguement Willson
# name: Willson
# age: 32
# country: Cameroon

# %%
# Return multiple parmeters 

def multiply(a, b):
    return a * b, a

multiply(2, 3)
# Out:
# (6, 2)
