# %%
"""
START
SET results to an empty list
WHILE number >= 0
    REMAINDER = number %2
    ADD remainder to the results list
    Number to the floor of num divided by 2
END WHILE
"""

# %%
num = 16

results = []

while num > 0:
    remiander = num % 2
    results.append(remiander)
    num = num // 2

for num in results[::-1]:
    print(num, end="")
# Out:
# 10000

# %%
def int_to_binary(n):
    """
    Function to convert integer to its binary representation without using inbuilt functions

    Parameters:
    n (int): The integer to convert.

    Returns:
    str: The binary representation of the integer
    """
    if n == 0:
        return "0" # special case for zero

    # Store binary representation
    binary_representation = ""

    # Handle negative numbers
    is_negative = n < 0
    if is_negative:
        n = -n # Work with the absolute value
    
    # Convert to binary
    while n > 0:
        remiander = n % 2
        binary_representation = str(remiander) + binary_representation # prepend remainder
        n = n // 2 # Update n to be m divided by 2 (floor division)

    # Add the negative sign for negative numbers
    if is_negative:
        binary_representation = "-" + binary_representation
    
    return binary_representation

print(int_to_binary(7))
# Out:
# 111
