# %%
## Tuples are ordered collections of items that are immutable. They are similar to lists, but thier immutability 
## makes it different

# %%
# creating a tuple

empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1, 2, 3, 4, 5, 6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1, 2, 3, 4, 5, 6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple = (1, "Hello world", 3.14, True)
print(mixed_tuple)
# Out:
# (1, 'Hello world', 3.14, True)

# %%
## Accessing tuple elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[2])
print(numbers[-1])
# Out:
# 3
# 6

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuple operations

concatenation_tuple = numbers + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello world', 3.14, True)

# %%
mixed_tuple * 3
# Out:
# (1,
#  'Hello world',
#  3.14,
#  True,
#  1,
#  'Hello world',
#  3.14,
#  True,
#  1,
#  'Hello world',
#  3.14,
#  True)

# %%
numbers * 3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutable nature of Tuples
## Tuples are immutable meaning the elements cannot be change when assingned

lst = [1, 2, 3, 4, 5]
print(lst)

lst[1] = "Krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Krish', 3, 4, 5]

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[1] = "Willson"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 numbers[1] = "Willson"
#
# TypeError: 'tuple' object does not support item assignment

# %%
## Tuple methods
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
## Packing and Unpacking tuples

# Packing
packed_tuple = 1, "Hello", 3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
# Unpacking a tuple

a, b, c = packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
# Unpacking with *

numbers = (1, 2, 3, 4, 5, 6)
first, *middle, last = numbers

print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested Tuple

## Nested list
lst = [[1, 2, 3, 4], [6, 7, 8, 9], [1, "Hello", 3.14, "c"]]

lst[2][0:3]
# Out:
# (1, 'Hello', 3.14)

# %%
lst = [[1, 2, 3, 4], [6, 7, 8, 9], (1, "Hello", 3.14, "c")]

lst[2][0:3]
# Out:
# (1, 'Hello', 3.14)

# %%
nested_tuple = ((1, 2, 3), ("a", "b", "c"), (True, False))

## Accessing the elements inside a tuple

print(nested_tuple[0])
print(nested_tuple[1][-1])
# Out:
# (1, 2, 3)
# c

# %%
# Iterating over nested tuple

for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item, end = " ")
    print()
# Out:
# 1 2 3
# a b c
# True False
