# %%
'''
5 x 2
*****
*****

psuedo code

GET the number of rows
GET the number of columns
FOR i in range of rows
For j in range of columns
Print *

'''

# %%
rows = int(input("Enter the number of rows: "))
columns = int(input("Enter the number of columns: "))

for i in range(rows):
    for j in range(columns):
        print('*', end=" ")
    print()
# Out:
# * * * * *
# * * * * *

# %%
def rectangle(n, m):
    """
    Function to return a rentangle of pattern of '*' with length n and breath m as a list of strings.

    parameters:

    n(int): The number of rows in the rectangle.
    m(int): The number of columns in the rectangle.

    Retuns:

    list: A list of strings each string represents a row of the rectangle pattern.
    """

    # Initialize an empty list to store the rows of the rectangle

    rectangle = []

    # loop through each row from 1 to n
    for _  in range(n):
        # create a row with m stars
        row = '*' * m
        # add each row to the rectangle list
        rectangle.append(row)

    # Return the list of rectangle rows

    return rectangle

print(rectangle(2, 5))
# Out:
# ['*****', '*****']
