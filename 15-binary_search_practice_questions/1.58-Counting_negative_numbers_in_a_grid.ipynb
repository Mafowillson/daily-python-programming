# %%
"""
START
GET the grid of numbers aligned in non increasing order
SET right = length of this row and left = 0
While Left < right 
    mid = (left + right) // 2
    If the element at the mid < 0
    right = mid
    ELSE
    left =  mid + 1
END
"""

# %%
def countNegatives(grid):
    """
    Count the numnber of negative numbers in a matrix sorted in non-increasing order
    both row-wise and colum-wise using binary search
    """

    def count_negatives_in_row(row):
        """
        Use binary search to count the number of negative numbers in a row.
        """

        left, right = 0, len(row)

        while left < right:
            mid = (left + right) // 2
            if row[mid] < 0:
                right = mid
            else:
                left = mid + 1
        
        return len(row) - left
    
    total_negative = 0
    for row in grid:
        total_negative += count_negatives_in_row(row)
    
    return total_negative

print(countNegatives([[4, 3, 2, 1], [3, 2, 1, -1], [1, 1, -1, -2], [-1, -1, -2, -3]]))
# Out:
# 7
