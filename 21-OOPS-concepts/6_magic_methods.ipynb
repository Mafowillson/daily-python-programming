# %% [markdown]
# ## Magic Methods
#
# Magic methods in python, also known as dunder methods(double underscore methods), are special methods that start and end with double underscores. These methods enable you to define the behavior of objects for built-in operations, such as arithmetic operations, comparisons, and more
#
# ## Magic Methods
#
# Magic methods are predefined methods in Python that you can override to change the behaviour of your objects. Some common magic methods include:
#
# * init: Initializes a new instance of a class
# * str: Returns a string representation of an object
# * repr: Returns an official string representation of an object.
# * len: returns the length of an object
# * getitem: Gets an item from a containger
# * setitem: sets an item in a container

# %%
class Person:
    pass

person = Person()

dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)
# Out:
# <__main__.Person object at 0x7073700b4910>

# %%
# Basic Methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person("Willson", 30)

print(person)
# Out:
# <__main__.Person object at 0x78d0f4cdb350>

# %%
# Basic Methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} - {self.age} years old"
    
    def __repr__(self):
        return f"person(name={self.name}, age={self.age})"

person = Person("Willson", 30)


print(person)
print(repr(person))
# Out:
# Willson - 30 years old
# person(name=Willson, age=30)
