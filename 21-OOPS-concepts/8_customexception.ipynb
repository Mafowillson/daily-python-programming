# %% [markdown]
# ## Custom exception (Raise and throw)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter the dob: "))
age = 2026 - year

try:
    if age <= 30 and age >= 20:
        print("The age is valid so you can apply for the exam")
    else:
        raise dobException
except dobException:
    print("Sorry, your age is not within the specified range for this exmas")
# Out:
# Sorry, your age is not within the specified range for this exmas
